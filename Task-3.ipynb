# %%
## DATASET-1 NETFLIX MOVIES AND TV SHOWS DATASET
# 1.Plot distribution of numerical features using histograms.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("netflix_titles.csv")
print(df.head())
plt.figure()
df['release_year'].hist(bins=20)
plt.xlabel("Release Year")
plt.ylabel("Count")
plt.title("Distribution of Release year")
plt.show()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# 2.Analyze categorical features using count plots.
plt.figure()
sns.countplot(x='type',data=df)
plt.title("Count of movies vs TV shows")
plt.show()

# %%
# 3.Use box plots to identify outliers.
plt.figure()
sns.barplot(x='type',y='release_year',data=df)
plt.title("Release year outliers by type")
plt.show()

# %%
# 4.Plot correlation heatmap to understand feature relationships.
num_df=df[['release_year']]
plt.figure()
sns.heatmap(num_df.corr(),annot=True)
plt.title("correlation heatmap")
plt.show()

# %%
# 5.Write insights for each visualization.
• Movies are more frequent than TV Shows.
• Most content is released after 2010.
• TV Shows tend to have slightly newer release years.
• Very weak correlation due to limited numerical features.

# %%
# 6.Identify features important for prediction.
• type
• rating
• release_year
• country
• duration

# %%
# 7.Summarize findings in bullet points.
Netflix Dataset:
• Mostly categorical data.
• Trend shows growth in content after 2010.
• Useful for recommendation and content analysis.

# %%
## DATASET-2 IRIS DATASET
# 1.Plot distribution of numerical features using histograms.
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df['species']=iris.target
df.head()
df.hist(figsize=(8,6))
plt.show()

# %%
# 2.Analyze categorical features using count plots.
plt.figure()
sns.countplot(x='species',data=df)
plt.title("Species distribution")
plt.show()

# %%
# 3.Use box plots to identify outliers.
plt.figure(figsize=(10,6))
sns.boxplot(data=df.drop('species',axis=1))
plt.xticks(rotation=45)
plt.title("Outlier detection using box plot")
plt.show()

# %%
# 4.Plot correlation heatmap to understand feature relationships.
plt.figure(figsize=(6,4))
sns.heatmap(df.drop('species',axis=1).corr(),annot=True,cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 5.Write insights for each visualization.
• Petal length and petal width are highly correlated.
• Setosa species is clearly separable.
• Some overlap exists between Versicolor and Virginica.
• No major outliers affecting the dataset.

# %%
# 6.Identify features important for prediction.
• petal length
• petal width
• sepal length

# %%
# 7.Summarize findings in bullet points.
Iris Dataset:
• Clean and balanced dataset.
• Strong correlations among petal features.
• Ideal for classification models.
